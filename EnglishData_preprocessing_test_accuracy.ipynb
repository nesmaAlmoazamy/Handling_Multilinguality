# %% [markdown]
# # Multilingual Text Dataset
#
# I created this dataset using free API from [Webhose](https://webhose.io/)
#
# This dataset contains blog posts labeled by language and by category.

# %%
import seaborn as sn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from nltk.corpus import stopwords
# %matplotlib inline

# %% [markdown]
# First, I need to import data in a dataframe.

# %%
dataset = pd.read_csv('data/dataset.csv', sep='\t', header=None).applymap(str)

# %% [markdown]
# then I'm getting labels for languages

# %%
languages = dataset[dataset.columns[0]].unique()
languages
# Out:
# array(['english', 'albanian', 'arabic', 'bulgarian', 'chinese',
#        'croatian', 'czech', 'danish', 'dutch', 'estonian', 'finnish',
#        'french', 'german', 'greek', 'hebrew', 'hungarian', 'icelandic',
#        'italian', 'japanese', 'korean', 'lithuanian', 'norwegian',
#        'polish', 'portuguese', 'romanian', 'russian', 'serbian',
#        'slovenian', 'spanish', 'swedish', 'turkish', 'ukrainian'],
#       dtype=object)

# %% [markdown]
# and labels for categories

# %%
categories = dataset[dataset.columns[1]].unique()
len(categories)
# Out:
# 45

# %% [markdown]
# now I'm going to create a dataframe containing the number of posts for any pair language/category

# %%
stats = pd.DataFrame(np.zeros([len(languages), len(categories)], dtype=int), index=[i for i in languages],
                     columns=[i for i in categories])

for _, row in dataset.iterrows():
    stats.loc[[row[0]], [row[1]]] += 1

# %% [markdown]
# Let's see how data is ditributed between labels

# %%
plt.figure(figsize=(20, 20))
sn.heatmap(stats, annot=True, cmap='Blues', fmt='g')
plt.show()

# %% [markdown]
# So now we have an inside look on how this dataset distribution is. It's obvious some category or language don't have much data so it's probably needed to discard it during use in any project.

# %%
# Rename Dataset Columns
dataset.columns = ["Language","Label","Text"]
dataset.head()
# Out:
#   Language        Label                                               Text
# 0  english  advertising  Exclusive: U.S. government seeks Facebook help...
# 1  english  advertising  Trump asks SEC to mull half-year corporate fil...
# 2  english  advertising  Wall St. up on trade hopes, S&P equals longest...
# 3  english  advertising  Asian shares hit one-year low on Turkey, China...
# 4  english  advertising  Asian stocks weaken as Turkey worries weigh, d...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
dataset["Label"] = label_encoder.fit_transform(dataset["Label"])
dataset.head()
# Out:
#   Language  Label                                               Text
# 0  english      1  Exclusive: U.S. government seeks Facebook help...
# 1  english      1  Trump asks SEC to mull half-year corporate fil...
# 2  english      1  Wall St. up on trade hopes, S&P equals longest...
# 3  english      1  Asian shares hit one-year low on Turkey, China...
# 4  english      1  Asian stocks weaken as Turkey worries weigh, d...

# %%
#Now we have a dataset for each language
languagesData=[]
loc = 0
for i in languages:
    name = languages[loc]+"Data" 
    globals()[name] = pd.DataFrame( dataset[dataset.Language == i])
    loc += 1

# %% [markdown]
# ## Preprocessing on English data:

# %% [markdown]
# 1. Convert text to lowercase

# %%
def lower_words(text):
    text = text.str.lower()
    return text

englishData['Text'] = lower_words(englishData['Text'])
input_str = englishData['Text']
print(englishData.head())
type(input_str)
# Out:
#   Language  Label                                               Text
# 0  english      1  exclusive: u.s. government seeks facebook help...
# 1  english      1  trump asks sec to mull half-year corporate fil...
# 2  english      1  wall st. up on trade hopes, s&p equals longest...
# 3  english      1  asian shares hit one-year low on turkey, china...
# 4  english      1  asian stocks weaken as turkey worries weigh, d...
# pandas.core.series.Series

# %% [markdown]
# 2. Remove URL's

# %%
def remove_url(text):
    text = text.apply(lambda x: re.split('https:\/\/.*', str(x))[0])
    return text


englishData['Text'] = remove_url(englishData['Text'])
englishData.head()
# Out:
#   Language  Label                                               Text
# 0  english      1  exclusive: u.s. government seeks facebook help...
# 1  english      1  trump asks sec to mull half-year corporate fil...
# 2  english      1  wall st. up on trade hopes, s&p equals longest...
# 3  english      1  asian shares hit one-year low on turkey, china...
# 4  english      1  asian stocks weaken as turkey worries weigh, d...

# %% [markdown]
# 3. Remove numbers

# %%
def remove_numbers(text):
    text = text.str.replace('\d+', '')
    return text


englishData['Text'] = remove_numbers(englishData['Text'])
englishData.head()
# Out:
#   Language  Label                                               Text
# 0  english      1  exclusive: u.s. government seeks facebook help...
# 1  english      1  trump asks sec to mull half-year corporate fil...
# 2  english      1  wall st. up on trade hopes, s&p equals longest...
# 3  english      1  asian shares hit one-year low on turkey, china...
# 4  english      1  asian stocks weaken as turkey worries weigh, d...

# %% [markdown]
# 4.  Remove punctuation:
#     * The following code removes this set of symbols [!”#$%&’()*+,-./:;<=>?@[\]^_`{|}~]:

# %%
def remove_punctuations(text):
    text = text.str.replace('[^\w\s]','')
    return text


englishData['Text'] = remove_punctuations(englishData['Text'])
englishData.head()
# Out:
#   Language  Label                                               Text
# 0  english      1  exclusive us government seeks facebook help to...
# 1  english      1  trump asks sec to mull halfyear corporate fili...
# 2  english      1  wall st up on trade hopes sp equals longest bu...
# 3  english      1  asian shares hit oneyear low on turkey china w...
# 4  english      1  asian stocks weaken as turkey worries weigh do...

# %% [markdown]
# 5. Remove whitespaces.

# %%
def remove_blank_space(col):
    col = col.str.strip()
    col = col.replace('\s+', ' ', regex=True)   
    return col


englishData['Text'] = remove_blank_space(englishData.Text)
englishData.head()
# Out:
#   Language  Label                                               Text
# 0  english      1  exclusive us government seeks facebook help to...
# 1  english      1  trump asks sec to mull halfyear corporate fili...
# 2  english      1  wall st up on trade hopes sp equals longest bu...
# 3  english      1  asian shares hit oneyear low on turkey china w...
# 4  english      1  asian stocks weaken as turkey worries weigh do...

# %% [markdown]
# 6. Remove stopping words

# %%
def remove_stop_words(text, stop):    
    text.apply(lambda x: [item for item in x if item not in stop])
    return text

stop = stopwords.words('english')
remove_stop_words(englishData['Text'],stop)
englishData.head()
# Out:
#   Language  Label                                               Text
# 0  english      1  exclusive us government seeks facebook help to...
# 1  english      1  trump asks sec to mull halfyear corporate fili...
# 2  english      1  wall st up on trade hopes sp equals longest bu...
# 3  english      1  asian shares hit oneyear low on turkey china w...
# 4  english      1  asian stocks weaken as turkey worries weigh do...

# %% [markdown]
# 7. Stemming

# %%
def stem_sentences(sentence):
    tokens = sentence.split()
    stemmed_tokens = [porter_stemmer.stem(token) for token in tokens]
    return ' '.join(stemmed_tokens)


porter_stemmer = PorterStemmer()
englishData['Text'] = englishData['Text'].apply(stem_sentences)
englishData.head()
# Out:
#   Language  Label                                               Text
# 0  english      1  exclus us govern seek facebook help to wiretap...
# 1  english      1  trump ask sec to mull halfyear corpor file vs ...
# 2  english      1  wall st up on trade hope sp equal longest bull...
# 3  english      1  asian share hit oneyear low on turkey china wo...
# 4  english      1  asian stock weaken as turkey worri weigh dolla...

# %% [markdown]
# 8. Lemmatization

# %%
def lemmatize_text(text):
    lemma_tokens =  [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]
    return ' '.join(lemma_tokens)



w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()
englishData['Text']  = englishData.Text.apply(lemmatize_text)
englishData.head()
# Out:
#   Language  Label                                               Text
# 0  english      1  exclus u govern seek facebook help to wiretap ...
# 1  english      1  trump ask sec to mull halfyear corpor file v q...
# 2  english      1  wall st up on trade hope sp equal longest bull...
# 3  english      1  asian share hit oneyear low on turkey china wo...
# 4  english      1  asian stock weaken a turkey worri weigh dollar...

# %%
ESentences = englishData.Text
Ey = englishData.Label

# %%
from sklearn.model_selection import train_test_split

Esentences_train, Esentences_test, Ey_train, Ey_test = train_test_split(
   ESentences, Ey, test_size=0.25, random_state=1000)

# %%
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(Esentences_train)

EX_train = tokenizer.texts_to_sequences(Esentences_train)
EX_test = tokenizer.texts_to_sequences(Esentences_test)

vocab_size = len(tokenizer.word_index) + 1  # Adding 1 because of reserved 0 index
# Out:
# Using TensorFlow backend.

# %%
def plot_history(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %%
from keras.preprocessing.sequence import pad_sequences

maxlen = 100

EX_train = pad_sequences(EX_train, padding='post', maxlen=maxlen)
EX_test = pad_sequences(EX_test, padding='post', maxlen=maxlen)

import keras
Ey_train = keras.utils.to_categorical(Ey_train)
Ey_test = keras.utils.to_categorical(Ey_test)

print(EX_train[0, :])
# Out:
# [1392   13 1392 2644 1400    2 3829    5 4516    1   44 1756 2804 2694
#   539 4431    3  203  214    6    1   70    4  196  814  474    1 2508
#    13   92  267 1392  762    1   81  224    6  566    3   20  563 3377
#   196  911  267   12    1 4906  575  814   52  367  692  637  312 3416
#     5 1264  758    6 1505   98   52  107 4274  267    1  653   51  176
#   242   22 4907  840    1 1368  163  123 1696   18   61   60  521    4
#   521    4 1572   12   18   40    8 2805 2116  777 2268   44  531 2916
#     1 2645]

# %%
from keras.models import Sequential
from keras import layers

embedding_dim = 50

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim, 
                           input_length=maxlen))
model.add(layers.Flatten())
model.add(layers.Dense(100, activation='relu'))
model.add(layers.Dense(45, activation='softmax'))
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 50)           3363900
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 5000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               500100
# _________________________________________________________________
# dense_2 (Dense)              (None, 45)                4545
# =================================================================
# Total params: 3,868,545
# Trainable params: 3,868,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(EX_train, Ey_train,
                    epochs=20,
                    verbose=True,
                    validation_data=(EX_test, Ey_test))
loss, accuracy = model.evaluate(EX_train, Ey_train, verbose=True)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(EX_test, Ey_test, verbose=True)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Train on 3389 samples, validate on 1130 samples
# Epoch 1/20
# 3389/3389 [==============================] - 13s 4ms/step - loss: 3.7232 - acc: 0.0779 - val_loss: 3.6118 - val_acc: 0.1018
# Epoch 2/20
# 3389/3389 [==============================] - 12s 4ms/step - loss: 2.8929 - acc: 0.3113 - val_loss: 3.1655 - val_acc: 0.1832
# Epoch 3/20
# 3389/3389 [==============================] - 12s 4ms/step - loss: 1.3544 - acc: 0.7704 - val_loss: 3.1731 - val_acc: 0.2159
# Epoch 4/20
# 3389/3389 [==============================] - 12s 3ms/step - loss: 0.5666 - acc: 0.8474 - val_loss: 3.2415 - val_acc: 0.2168
# Epoch 5/20
# 3389/3389 [==============================] - 12s 4ms/step - loss: 0.4275 - acc: 0.8675 - val_loss: 3.2932 - val_acc: 0.2221
# Epoch 6/20
# 3389/3389 [==============================] - 13s 4ms/step - loss: 0.3837 - acc: 0.8708 - val_loss: 3.2952 - val_acc: 0.2345
# Epoch 7/20
# 3389/3389 [==============================] - 13s 4ms/step - loss: 0.3315 - acc: 0.8725 - val_loss: 3.3695 - val_acc: 0.2416
# Epoch 8/20
# 3389/3389 [==============================] - 12s 3ms/step - loss: 0.3122 - acc: 0.8781 - val_loss: 3.2894 - val_acc: 0.2389
# Epoch 9/20
# 3389/3389 [==============================] - 12s 3ms/step - loss: 0.3141 - acc: 0.8743 - val_loss: 3.2515 - val_acc: 0.2389
# Epoch 10/20
# 3389/3389 [==============================] - 11s 3ms/step - loss: 0.2991 - acc: 0.8758 - val_loss: 3.2749 - val_acc: 0.2310
# Epoch 11/20
# 3389/3389 [==============================] - 11s 3ms/step - loss: 0.2870 - acc: 0.8752 - val_loss: 3.3380 - val_acc: 0.2398
# Epoch 12/20
# 3389/3389 [==============================] - 12s 4ms/step - loss: 0.2764 - acc: 0.8772 - val_loss: 3.2901 - val_acc: 0.2398
# Epoch 13/20
# 3389/3389 [==============================] - 9s 3ms/step - loss: 0.2696 - acc: 0.8805 - val_loss: 3.2401 - val_acc: 0.2478
# Epoch 14/20
# 3389/3389 [==============================] - 8s 2ms/step - loss: 0.2703 - acc: 0.8731 - val_loss: 3.3504 - val_acc: 0.2381
# Epoch 15/20
# 3389/3389 [==============================] - 11s 3ms/step - loss: 0.2638 - acc: 0.8778 - val_loss: 3.3382 - val_acc: 0.2345
# Epoch 16/20
# 3389/3389 [==============================] - 10s 3ms/step - loss: 0.2546 - acc: 0.8734 - val_loss: 3.2941 - val_acc: 0.2372
# Epoch 17/20
# 3389/3389 [==============================] - 10s 3ms/step - loss: 0.2548 - acc: 0.8805 - val_loss: 3.2964 - val_acc: 0.2407
# Epoch 18/20
# 3389/3389 [==============================] - 10s 3ms/step - loss: 0.2507 - acc: 0.8749 - val_loss: 3.2550 - val_acc: 0.2407
# Epoch 19/20
# 3389/3389 [==============================] - 11s 3ms/step - loss: 0.2449 - acc: 0.8787 - val_loss: 3.3409 - val_acc: 0.2381
# Epoch 20/20
# 3389/3389 [==============================] - 10s 3ms/step - loss: 0.2434 - acc: 0.8740 - val_loss: 3.3229 - val_acc: 0.2336
# 3389/3389 [==============================] - 0s 120us/step
# Training Accuracy: 0.9085
# 1130/1130 [==============================] - 0s 117us/step
# Testing Accuracy:  0.2336

# %%
plot_history(history)

# %% [markdown]
# Using pretrained word embeddings

# %%
import numpy as np

def create_embedding_matrix(filepath, word_index, embedding_dim):
    vocab_size = len(word_index) + 1  # Adding again 1 because of reserved 0 index
    embedding_matrix = np.zeros((vocab_size, embedding_dim))

    with open(filepath) as f:
        for line in f:
            word, *vector = line.split()
            if word in word_index:
                idx = word_index[word] 
                embedding_matrix[idx] = np.array(
                    vector, dtype=np.float32)[:embedding_dim]

    return embedding_matrix

# %%
embedding_dim = 50
embedding_matrix = create_embedding_matrix(
    'glove.6B.50d.txt',
    tokenizer.word_index, embedding_dim)

# %%
nonzero_elements = np.count_nonzero(np.count_nonzero(embedding_matrix, axis=1))
nonzero_elements / vocab_size
# Out:
# 0.33749516929754153

# %%
from keras.layers import GRU,Dropout,BatchNormalization
model = Sequential()
model.add(layers.Embedding(vocab_size, embedding_dim, 
                           weights=[embedding_matrix], 
                           input_length=maxlen, 
                           trainable=True))
model.add(GRU(256))
model.add(Dropout(0.2))
model.add(layers.Dense(45, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 100, 50)           3363900
# _________________________________________________________________
# gru_1 (GRU)                  (None, 256)               235776
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 45)                11565
# =================================================================
# Total params: 3,611,241
# Trainable params: 3,611,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(EX_train, Ey_train,
                    epochs=10,
                    verbose=True,
                    validation_data=(EX_test, Ey_test)
                   )
loss, accuracy = model.evaluate(EX_train, Ey_train, verbose=True)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(EX_test, Ey_test, verbose=True)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# Train on 3389 samples, validate on 1130 samples
# Epoch 1/10
# 3389/3389 [==============================] - 48s 14ms/step - loss: 3.7389 - acc: 0.0626 - val_loss: 3.6465 - val_acc: 0.0850
# Epoch 2/10
# 3389/3389 [==============================] - 45s 13ms/step - loss: 3.5487 - acc: 0.1151 - val_loss: 3.5070 - val_acc: 0.0885
# Epoch 3/10
# 3389/3389 [==============================] - 45s 13ms/step - loss: 3.2233 - acc: 0.1564 - val_loss: 3.2454 - val_acc: 0.1593
# Epoch 4/10
# 3389/3389 [==============================] - 46s 14ms/step - loss: 2.8335 - acc: 0.2493 - val_loss: 2.9990 - val_acc: 0.2265
# Epoch 5/10
# 3389/3389 [==============================] - 47s 14ms/step - loss: 2.4828 - acc: 0.3255 - val_loss: 2.8320 - val_acc: 0.2699
# Epoch 6/10
# 3389/3389 [==============================] - 44s 13ms/step - loss: 2.1604 - acc: 0.3936 - val_loss: 2.7864 - val_acc: 0.2584
# Epoch 7/10
# 3389/3389 [==============================] - 42s 12ms/step - loss: 1.8661 - acc: 0.4653 - val_loss: 2.7139 - val_acc: 0.2912
# Epoch 8/10
# 3389/3389 [==============================] - 41s 12ms/step - loss: 1.6028 - acc: 0.5276 - val_loss: 2.6630 - val_acc: 0.2991
# Epoch 9/10
# 3389/3389 [==============================] - 39s 11ms/step - loss: 1.3679 - acc: 0.6043 - val_loss: 2.6955 - val_acc: 0.2965
# Epoch 10/10
# 3389/3389 [==============================] - 40s 12ms/step - loss: 1.2015 - acc: 0.6356 - val_loss: 2.7071 - val_acc: 0.3345
# 3389/3389 [==============================] - 8s 2ms/step
# Training Accuracy: 0.7359
# 1130/1130 [==============================] - 3s 2ms/step
# Testing Accuracy:  0.3345

# %%
history = model.fit(EX_train, Ey_train,
                    epochs=50,
                    verbose=True,
                    validation_data=(EX_test, Ey_test)
                   )
loss, accuracy = model.evaluate(EX_train, Ey_train, verbose=True)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(EX_test, Ey_test, verbose=True)
print("Testing Accuracy:  {:.4f}".format(accuracy))
plot_history(history)
# Out:
# Train on 3389 samples, validate on 1130 samples
# Epoch 1/50
# 3389/3389 [==============================] - 49s 14ms/step - loss: 0.9691 - acc: 0.7108 - val_loss: 2.7601 - val_acc: 0.3283
# Epoch 2/50
# 3389/3389 [==============================] - 42s 12ms/step - loss: 0.8312 - acc: 0.7501 - val_loss: 2.7239 - val_acc: 0.3487
# Epoch 3/50
# 3389/3389 [==============================] - 40s 12ms/step - loss: 0.6955 - acc: 0.7952 - val_loss: 2.8268 - val_acc: 0.3451
# Epoch 4/50
# 3389/3389 [==============================] - 44s 13ms/step - loss: 0.5956 - acc: 0.8147 - val_loss: 2.8178 - val_acc: 0.3487
# Epoch 5/50
# 3389/3389 [==============================] - 46s 13ms/step - loss: 0.5105 - acc: 0.8318 - val_loss: 2.8925 - val_acc: 0.3416
# Epoch 6/50
# 3389/3389 [==============================] - 42s 13ms/step - loss: 0.4728 - acc: 0.8401 - val_loss: 2.9180 - val_acc: 0.3540
# Epoch 7/50
# 3389/3389 [==============================] - 41s 12ms/step - loss: 0.3936 - acc: 0.8584 - val_loss: 3.0933 - val_acc: 0.3460
# Epoch 8/50
# 3389/3389 [==============================] - 45s 13ms/step - loss: 0.4053 - acc: 0.8563 - val_loss: 3.0385 - val_acc: 0.3451
# Epoch 9/50
# 3389/3389 [==============================] - 45s 13ms/step - loss: 0.3435 - acc: 0.8675 - val_loss: 3.0838 - val_acc: 0.3513
# Epoch 10/50
# 3389/3389 [==============================] - 46s 14ms/step - loss: 0.3110 - acc: 0.8781 - val_loss: 3.2285 - val_acc: 0.3566
# Epoch 11/50
# 3389/3389 [==============================] - 48s 14ms/step - loss: 0.2969 - acc: 0.8772 - val_loss: 3.2246 - val_acc: 0.3434
# Epoch 12/50
# 3389/3389 [==============================] - 47s 14ms/step - loss: 0.2945 - acc: 0.8808 - val_loss: 3.2544 - val_acc: 0.3549
# Epoch 13/50
# 3389/3389 [==============================] - 47s 14ms/step - loss: 0.2704 - acc: 0.8843 - val_loss: 3.3229 - val_acc: 0.3549
# Epoch 14/50
# 3389/3389 [==============================] - 47s 14ms/step - loss: 0.2487 - acc: 0.8843 - val_loss: 3.3472 - val_acc: 0.3460
# Epoch 15/50
# 3389/3389 [==============================] - 40s 12ms/step - loss: 0.2278 - acc: 0.8932 - val_loss: 3.4028 - val_acc: 0.3496
# Epoch 16/50
# 3389/3389 [==============================] - 46s 14ms/step - loss: 0.2149 - acc: 0.8876 - val_loss: 3.4735 - val_acc: 0.3442
# Epoch 17/50
# 3389/3389 [==============================] - 46s 13ms/step - loss: 0.2112 - acc: 0.8929 - val_loss: 3.4642 - val_acc: 0.3451
# Epoch 18/50
# 3389/3389 [==============================] - 46s 13ms/step - loss: 0.2075 - acc: 0.8973 - val_loss: 3.5292 - val_acc: 0.3442
# Epoch 19/50
# 3389/3389 [==============================] - 47s 14ms/step - loss: 0.2253 - acc: 0.8938 - val_loss: 3.5125 - val_acc: 0.3398
# Epoch 20/50
# 3389/3389 [==============================] - 46s 13ms/step - loss: 0.2338 - acc: 0.8852 - val_loss: 3.5808 - val_acc: 0.3274
# Epoch 21/50
# 3389/3389 [==============================] - 40s 12ms/step - loss: 0.2211 - acc: 0.8917 - val_loss: 3.6279 - val_acc: 0.3425
# Epoch 22/50
# 3389/3389 [==============================] - 42s 12ms/step - loss: 0.2035 - acc: 0.8964 - val_loss: 3.6615 - val_acc: 0.3442
# Epoch 23/50
# 3389/3389 [==============================] - 46s 13ms/step - loss: 0.2359 - acc: 0.8920 - val_loss: 3.6777 - val_acc: 0.3212
# Epoch 24/50
# 3389/3389 [==============================] - 46s 13ms/step - loss: 0.2496 - acc: 0.8858 - val_loss: 3.6649 - val_acc: 0.3345
# Epoch 25/50
# 3389/3389 [==============================] - 47s 14ms/step - loss: 0.2106 - acc: 0.8976 - val_loss: 3.6412 - val_acc: 0.3398
# Epoch 26/50
# 3389/3389 [==============================] - 47s 14ms/step - loss: 0.1965 - acc: 0.8979 - val_loss: 3.6928 - val_acc: 0.3372
# Epoch 27/50
# 3389/3389 [==============================] - 48s 14ms/step - loss: 0.2116 - acc: 0.8997 - val_loss: 3.6991 - val_acc: 0.3416
# Epoch 28/50
# 3389/3389 [==============================] - 48s 14ms/step - loss: 0.1935 - acc: 0.8964 - val_loss: 3.7638 - val_acc: 0.3425
# Epoch 29/50
# 3389/3389 [==============================] - 47s 14ms/step - loss: 0.2475 - acc: 0.8885 - val_loss: 3.5979 - val_acc: 0.3398
# Epoch 30/50
# 3389/3389 [==============================] - 47s 14ms/step - loss: 0.2227 - acc: 0.8908 - val_loss: 3.7684 - val_acc: 0.3301
# Epoch 31/50
# 3389/3389 [==============================] - 44s 13ms/step - loss: 0.2037 - acc: 0.8970 - val_loss: 3.7764 - val_acc: 0.3425
# Epoch 32/50
# 3389/3389 [==============================] - 41s 12ms/step - loss: 0.1862 - acc: 0.9032 - val_loss: 3.8471 - val_acc: 0.3372
# Epoch 33/50
# 3389/3389 [==============================] - 48s 14ms/step - loss: 0.1816 - acc: 0.9026 - val_loss: 3.9294 - val_acc: 0.3425
# Epoch 34/50
# 3389/3389 [==============================] - 48s 14ms/step - loss: 0.1715 - acc: 0.9029 - val_loss: 3.8895 - val_acc: 0.3416
# Epoch 35/50
# 3389/3389 [==============================] - 53s 16ms/step - loss: 0.1693 - acc: 0.9012 - val_loss: 3.9683 - val_acc: 0.3292
# Epoch 36/50
# 3389/3389 [==============================] - 51s 15ms/step - loss: 0.1698 - acc: 0.9035 - val_loss: 3.9947 - val_acc: 0.3354
# Epoch 37/50
# 3389/3389 [==============================] - 51s 15ms/step - loss: 0.1640 - acc: 0.9026 - val_loss: 4.0230 - val_acc: 0.3416
# Epoch 38/50
# 3389/3389 [==============================] - 49s 14ms/step - loss: 0.1678 - acc: 0.9062 - val_loss: 4.0690 - val_acc: 0.3416
# Epoch 39/50
# 3389/3389 [==============================] - 44s 13ms/step - loss: 0.1995 - acc: 0.8935 - val_loss: 3.9717 - val_acc: 0.3319
# Epoch 40/50
# 3389/3389 [==============================] - 42s 12ms/step - loss: 0.1876 - acc: 0.8964 - val_loss: 4.0291 - val_acc: 0.3319
# Epoch 41/50
# 3389/3389 [==============================] - 44s 13ms/step - loss: 0.1753 - acc: 0.9065 - val_loss: 4.0525 - val_acc: 0.3319
# Epoch 42/50
# 3389/3389 [==============================] - 42s 12ms/step - loss: 0.1654 - acc: 0.9026 - val_loss: 4.1466 - val_acc: 0.3310
# Epoch 43/50
# 3389/3389 [==============================] - 42s 12ms/step - loss: 0.1636 - acc: 0.9032 - val_loss: 4.1427 - val_acc: 0.3310
# Epoch 44/50
# 3389/3389 [==============================] - 46s 13ms/step - loss: 0.1782 - acc: 0.9000 - val_loss: 4.0591 - val_acc: 0.3327
# Epoch 45/50
# 3389/3389 [==============================] - 46s 14ms/step - loss: 0.1864 - acc: 0.8994 - val_loss: 4.2220 - val_acc: 0.3381
# Epoch 46/50
# 3389/3389 [==============================] - 43s 13ms/step - loss: 0.1994 - acc: 0.8938 - val_loss: 4.1010 - val_acc: 0.3434
# Epoch 47/50
# 3389/3389 [==============================] - 51s 15ms/step - loss: 0.1843 - acc: 0.8982 - val_loss: 4.0697 - val_acc: 0.3195
# Epoch 48/50
# 3389/3389 [==============================] - 42s 12ms/step - loss: 0.1711 - acc: 0.9044 - val_loss: 4.2185 - val_acc: 0.3389
# Epoch 49/50
# 3389/3389 [==============================] - 35s 10ms/step - loss: 0.1712 - acc: 0.9041 - val_loss: 4.1342 - val_acc: 0.3389
# Epoch 50/50
# 3389/3389 [==============================] - 21s 6ms/step - loss: 0.1669 - acc: 0.9006 - val_loss: 4.2625 - val_acc: 0.3354
# 3389/3389 [==============================] - 4s 1ms/step
# Training Accuracy: 0.9091
# 1130/1130 [==============================] - 1s 1ms/step
# Testing Accuracy:  0.3354
