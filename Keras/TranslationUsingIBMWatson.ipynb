# %% [markdown]
# # Translation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('../data/dataset.csv', sep='\t', header=None).applymap(str)
languages = dataset[dataset.columns[0]].unique()
categories = dataset[dataset.columns[1]].unique()

# %%
languages
# Out:
# array(['english', 'albanian', 'arabic', 'bulgarian', 'chinese',
#        'croatian', 'czech', 'danish', 'dutch', 'estonian', 'finnish',
#        'french', 'german', 'greek', 'hebrew', 'hungarian', 'icelandic',
#        'italian', 'japanese', 'korean', 'lithuanian', 'norwegian',
#        'polish', 'portuguese', 'romanian', 'russian', 'serbian',
#        'slovenian', 'spanish', 'swedish', 'turkish', 'ukrainian'],
#       dtype=object)

# %%
dataset.head()
# Out:
#          0            1                                                  2
# 0  english  advertising  Exclusive: U.S. government seeks Facebook help...
# 1  english  advertising  Trump asks SEC to mull half-year corporate fil...
# 2  english  advertising  Wall St. up on trade hopes, S&P equals longest...
# 3  english  advertising  Asian shares hit one-year low on Turkey, China...
# 4  english  advertising  Asian stocks weaken as Turkey worries weigh, d...

# %%
# Rename Dataset Columns
dataset.columns = ["language","label","text"]
dataset.head()
languagesData=[]
loc = 0
for i in languages:
    name = languages[loc]+"Data" 
    globals()[name] = pd.DataFrame( dataset[dataset.language == i])
    loc += 1

# %% [markdown]
# # Watson IBM POC

# %%
# available languages
import json
from ibm_watson import LanguageTranslatorV3
language_translator = LanguageTranslatorV3(
    version='2019-05-30',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='0OikiP4vprsFkwEoEAIQam-u7E-cZ6aBjdHh_6iWqtjU')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # Arabic

# %%
# coding=utf-8
from __future__ import print_function
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

mylist = []
language_translator = LanguageTranslatorV3(
    version='2019-05-30',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='0OikiP4vprsFkwEoEAIQam-u7E-cZ6aBjdHh_6iWqtjU')

df = pd.DataFrame(arabicData["label"]) 
df["text"] = arabicData['text'].str.split().str[1:50].str.join(" ")
translation =  df.text.map(lambda x: language_translator.translate(x, model_id='ar-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('arabicTranslated.csv', index=False, header=False)
arabicTranslated = pd.read_csv('arabicTranslated.csv',header=None)

arabicTranslated.columns = ["text"]
arabicTranslated.head()

# %%
arabicTranslated["label"] = list(arabicData["label"])
arabicTranslated.head()
# Out:
#                                                 text          label
# 0  Today on the ON channel 2 the Egyptian league ...  entertainment
# 1  Hwasa asks about her favorite member of the Bi...  entertainment
# 2  He was a biter who respected the state and my ...  entertainment
# 3  Boom salutes her fans as an artist from DNA fo...  entertainment
# 4  Team F and Arab Contractors team to face them ...  entertainment

# %% [markdown]
# # French

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3
df = pd.DataFrame(frenchData["label"]) 
df["text"] = frenchData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-05-30',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='0OikiP4vprsFkwEoEAIQam-u7E-cZ6aBjdHh_6iWqtjU')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-05-30',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='0OikiP4vprsFkwEoEAIQam-u7E-cZ6aBjdHh_6iWqtjU')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='fr-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('frenchTranslated.csv', index=False, header=False)

frenchTranslated = pd.read_csv('frenchTranslated.csv',header=None)

frenchTranslated.columns = ["text"]
frenchTranslated.head()

frenchTranslated["label"] = list(frenchData["label"])
frenchTranslated.head()

# %% [markdown]
# # Spanish

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3
df = pd.DataFrame(spanishData["label"]) 
df["text"] = spanishData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-07',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='wAqs7jHPGdsN35IpZXuoaark-8r90lWlfnHIZlTq35T0')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-06-07',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='wAqs7jHPGdsN35IpZXuoaark-8r90lWlfnHIZlTq35T0')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='es-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('spanishTranslated.csv', index=False, header=False)

spanishTranslated = pd.read_csv('spanishTranslated.csv',header=None)

spanishTranslated.columns = ["text"]
spanishTranslated.head()

spanishTranslated["label"] = list(spanishData["label"])
spanishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # Turkish

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3
df = pd.DataFrame(turkishData["label"]) 
df["text"] = turkishData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-05-30',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='wAqs7jHPGdsN35IpZXuoaark-8r90lWlfnHIZlTq35T0')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-05-30',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='wAqs7jHPGdsN35IpZXuoaark-8r90lWlfnHIZlTq35T0')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='tr-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('turkishData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('turkishData.csv',header=None)

turkishTranslated.columns = ["text"]
turkishTranslated.head()

turkishTranslated["label"] = list(turkishData["label"])
turkishTranslated.head()

# %% [markdown]
# # ukranina

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3
df = pd.DataFrame(ukrainianData["label"]) 

df["text"] = ukrainianData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-09',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='hrbLg4Soa7oxQXBL0-kTqwtHG1lunZFkEEfgmvROyzLf')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-05-30',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='hrbLg4Soa7oxQXBL0-kTqwtHG1lunZFkEEfgmvROyzLf')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='uk-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('italianData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('ukrainianData.csv',header=None)

turkishTranslated.columns = ["text"]
turkishTranslated.head()

turkishTranslated["label"] = list(ukrainianData["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# no estonina?
# no Albanian?
# no bulgarian?
# no Chinees?
# no crotian?
# no greek?
# no herbrew?

# %% [markdown]
# # Swedish

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3
df = pd.DataFrame(swedishData["label"]) 

df["text"] = swedishData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='a2EmTW-hUT-eJj2SfvYRo2G_n48djdNuL2DvcBw7G78L')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-05-30',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='a2EmTW-hUT-eJj2SfvYRo2G_n48djdNuL2DvcBw7G78L')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='sv-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('swedishData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('swedishData.csv',header=None)

turkishTranslated.columns = ["text"]
turkishTranslated.head()

turkishTranslated["label"] = list(swedishData["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # czechData

# %%
danishData.head()
# Out:
#       language        label                                               text
# 12796   danish  advertising  Forside » Nyheder » H+H øger indtjeninge.. « 1...
# 12797   danish  advertising  04 sep: Nordea siger farvel til chef for Perso...
# 12798   danish  advertising  16 aug: WDH/Carnegie: Anbefalingen sænkes til ...
# 12799   danish  advertising  Forside » Nyheder » Vestas: Igen højere .. « 1...
# 12800   danish  advertising  23 aug: Ambu fortsætter i vækstsporet og opjus...

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

df = pd.DataFrame(czechData["label"]) 
df["text"] = czechData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='a2EmTW-hUT-eJj2SfvYRo2G_n48djdNuL2DvcBw7G78L')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-05-30',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='a2EmTW-hUT-eJj2SfvYRo2G_n48djdNuL2DvcBw7G78L')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='cs-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('czechData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('czechData.csv',header=None)

turkishTranslated.columns = ["text"]

turkishTranslated["label"] = list(czechData["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # German

# %%
germanData.head()
# Out:
#       language        label                                               text
# 24042   german  advertising  14.08.2018 - 14:19 Ein Ass auf dem Basketballp...
# 24043   german  advertising  14.08.2018 - 12:40 Kollaboration der Superlati...
# 24044   german  advertising  13.08.2018 - 15:49 Unglaublicher WeltrekordAll...
# 24045   german  advertising  FacebookHachenburg (ots) – Am Montagabend, 20....
# 24046   german  advertising  FacebookPfalzfeld (ots) – Am frühen Dienstagmo...

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

df = pd.DataFrame(germanData["label"]) 
df["text"] = germanData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='a2EmTW-hUT-eJj2SfvYRo2G_n48djdNuL2DvcBw7G78L')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-05-30',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='a2EmTW-hUT-eJj2SfvYRo2G_n48djdNuL2DvcBw7G78L')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='de-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('germanData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('germanData.csv',header=None)

turkishTranslated.columns = ["text"]

turkishTranslated["label"] = list(germanData["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # finnish

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

df = pd.DataFrame(finnishData["label"]) 
df["text"] = finnishData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='a2EmTW-hUT-eJj2SfvYRo2G_n48djdNuL2DvcBw7G78L')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-05-30',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='a2EmTW-hUT-eJj2SfvYRo2G_n48djdNuL2DvcBw7G78L')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='fi-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('finnishData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('finnishData.csv',header=None)

turkishTranslated.columns = ["text"]

turkishTranslated["label"] = list(finnishData["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # hungrian

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

df = pd.DataFrame(hungarianData["label"]) 
df["text"] = hungarianData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='a2EmTW-hUT-eJj2SfvYRo2G_n48djdNuL2DvcBw7G78L')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-05-30',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='a2EmTW-hUT-eJj2SfvYRo2G_n48djdNuL2DvcBw7G78L')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='hu-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('hungarianData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('hungarianData.csv',header=None)

turkishTranslated.columns = ["text"]

turkishTranslated["label"] = list(hungarianData["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # iclendic

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

df = pd.DataFrame(italianData["label"]) 
df["text"] = italianData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='Nbh57tUd2Rwc4kTTp8iCPMjwkj_AD82ZFusz3Dsy0xZG')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='Nbh57tUd2Rwc4kTTp8iCPMjwkj_AD82ZFusz3Dsy0xZG')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='it-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('italianData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('italianData.csv',header=None)

turkishTranslated.columns = ["text"]

turkishTranslated["label"] = list(italianData["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # KoreanData

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

df = pd.DataFrame(koreanData["label"]) 
df["text"] = koreanData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='Nbh57tUd2Rwc4kTTp8iCPMjwkj_AD82ZFusz3Dsy0xZG')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='Nbh57tUd2Rwc4kTTp8iCPMjwkj_AD82ZFusz3Dsy0xZG')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='ko-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('koreanData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('koreanData.csv',header=None)

turkishTranslated.columns = ["text"]

turkishTranslated["label"] = list(koreanData["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # lithuanian?
#
# # norwegan

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

df = pd.DataFrame(norwegianData["label"]) 
df["text"] = norwegianData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='Nbh57tUd2Rwc4kTTp8iCPMjwkj_AD82ZFusz3Dsy0xZG')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='Nbh57tUd2Rwc4kTTp8iCPMjwkj_AD82ZFusz3Dsy0xZG')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='nb-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('norwegianData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('norwegianData.csv',header=None)

turkishTranslated.columns = ["text"]

turkishTranslated["label"] = list(norwegianData["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # polish

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

df = pd.DataFrame(polishData["label"]) 
df["text"] = polishData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='Nbh57tUd2Rwc4kTTp8iCPMjwkj_AD82ZFusz3Dsy0xZG')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='Nbh57tUd2Rwc4kTTp8iCPMjwkj_AD82ZFusz3Dsy0xZG')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='pl-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('polishData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('polishData.csv',header=None)

turkishTranslated.columns = ["text"]

turkishTranslated["label"] = list(polishData["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # portagues

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

df = pd.DataFrame(portugueseData["label"]) 
df["text"] = portugueseData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='Nbh57tUd2Rwc4kTTp8iCPMjwkj_AD82ZFusz3Dsy0xZG')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='Nbh57tUd2Rwc4kTTp8iCPMjwkj_AD82ZFusz3Dsy0xZG')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='pt-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('portugueseData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('portugueseData.csv',header=None)

turkishTranslated.columns = ["text"]

turkishTranslated["label"] = list(portugueseData["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # russian

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

df = pd.DataFrame(russianData["label"]) 
df["text"] = russianData['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='Nbh57tUd2Rwc4kTTp8iCPMjwkj_AD82ZFusz3Dsy0xZG')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='Nbh57tUd2Rwc4kTTp8iCPMjwkj_AD82ZFusz3Dsy0xZG')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='ru-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('russianData.csv', index=False, header=False)

turkishTranslated = pd.read_csv('russianData.csv',header=None)

turkishTranslated.columns = ["text"]

turkishTranslated["label"] = list(russianData["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %% [markdown]
# # Round trip

# %%
english1 = pd.read_csv('EnglishDataTrainingPartPreparedforRounTrip.csv')
english1.head()
# Out:
#          Label                                               Text
# 0  advertising  Exclusive: U.S. government seeks Facebook help...
# 1  advertising  Trump asks SEC to mull half-year corporate fil...
# 2  advertising  Wall St. up on trade hopes, S&P equals longest...
# 3  advertising  Asian shares hit one-year low on Turkey, China...
# 4  advertising  Musk bid for Tesla: no formal offer, no firm d...

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

df = pd.DataFrame(english1["Label"]) 
df["text"] = english1['Text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-11',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='rG5QKXTkknRUGXeVZYrlH16Z3cvIx2A-c9s7JhQWieZ9')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='rG5QKXTkknRUGXeVZYrlH16Z3cvIx2A-c9s7JhQWieZ9')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='en-de').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('english_to_german.csv', index=False, header=False)

turkishTranslated = pd.read_csv('english_to_german.csv',header=None)

turkishTranslated.columns = ["text"]

turkishTranslated["label"] = list(english1["Label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...

# %%
english_to_german = pd.read_csv('english_to_german.csv')
english_to_german.head()
# Out:
#    Unnamed: 0                                               text        label
# 0           0  {'translations': [{'translation': 'U.S. Regier...  advertising
# 1           1  {'translations': [{'translation': 'fordert SEC...  advertising
# 2           2  {'translations': [{'translation': 'St. up auf ...  advertising
# 3           3  {'translations': [{'translation': 'Die Aktien ...  advertising
# 4           4  {'translations': [{'translation': "Geboten für...  advertising

# %%
from __future__ import print_function
import pandas as pd
from requests.exceptions import Timeout
import json
from ibm_watson import LanguageTranslatorV3

df = pd.DataFrame(english_to_german["label"]) 
df["text"] = english_to_german['text'].str.split().str[1:50].str.join(" ")

import json
from ibm_watson import LanguageTranslatorV3

language_translator = LanguageTranslatorV3(
    version='2019-06-11',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='rG5QKXTkknRUGXeVZYrlH16Z3cvIx2A-c9s7JhQWieZ9')

languages = language_translator.list_identifiable_languages().get_result()
print(json.dumps(languages, indent=2))


language_translator = LanguageTranslatorV3(
    version='2019-06-10',
    ### url is optional, and defaults to the URL below. Use the correct URL for your region.
    url='https://gateway-lon.watsonplatform.net/language-translator/api',
    iam_apikey='rG5QKXTkknRUGXeVZYrlH16Z3cvIx2A-c9s7JhQWieZ9')

translation =  df.text.map(lambda x: language_translator.translate(x, model_id='de-en').get_result())

my_df = pd.DataFrame(translation)
my_df.to_csv('german_to_english.csv', index=False, header=False)

turkishTranslated = pd.read_csv('german_to_english.csv',header=None)

turkishTranslated.columns = ["text"]

turkishTranslated["label"] = list(english_to_german["label"])
turkishTranslated.head()
# Out:
# {
#   "languages": [
#     {
#       "language": "af",
#       "name": "Afrikaans"
#     },
#     {
#       "language": "ar",
#       "name": "Arabic"
#     },
#     {
#       "language": "az",
#       "name": "Azerbaijani"
#     },
#     {
#       "language": "ba",
#       "name": "Bashkir"
#     },
#     {
#       "language": "be",
#       "name": "Belarusian"
#     },
#     {
#       "language": "bg",
#       "name": "Bulgarian"
#     },
#     {
#       "language": "bn",
#       "name": "Bengali"
#     },
#     {
#       "language": "bs",
#       "name": "Bosnian"
#     },
#     {
#       "language": "ca",
#       "name": "Catalan"
#     },
#     {
#       "language": "cs",
#       "name": "Czech"
#     },
#     {
#       "language": "cv",
#       "name": "Chuvash"
#     },
#     {
#       "language": "da",
#       "name": "Danish"
#     },
#     {
#       "language": "de",
#       "name": "German"
#     },
#     {
#       "language": "el",
#       "name": "Greek"
#     },
# ...
